# %% [markdown]
# # Student Exercise

# %% [markdown]
# # Imports

# %% [markdown]
# # Dataset

# %% [markdown]
# - '#': ID for each pokemon
# - Name: Name of each pokemon
# - Type 1: Each pokemon has a type, this determines weakness/resistance to attacks
# - Type 2: Some pokemon are dual type and have 2
# - Total: sum of all stats that come after this, a general guide to how strong a pokemon is
# - HP: hit points, or health, defines how much damage a pokemon can withstand before fainting
# - Attack: the base modifier for normal attacks (eg. Scratch, Punch)
# - Defense: the base damage resistance against normal attacks
# - SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# - SP Def: the base damage resistance against special attacks
# - Speed: determines which pokemon attacks first each round

# %% [markdown]
# # Load Data

# %% [markdown]
# # Preguntas

# %% [markdown]
# ## 1. ¿Cual es la distribución de HP?

# %% [markdown]
# ## 2. ¿Cual es la distribución en un solo gráfico de las siguientes características (HP, Attack,Defense,Sp. Atk,Sp. Def,Speed)?

# %% [markdown]
# ## 3. ¿Existen valores anomalos de las variables anteriores? (Box Plot)

# %% [markdown]
# ## 4. ¿Podrias visualizar las caracteristicas de Charizard a través de un diagrama de araña? (Scatterpolar)

# %% [markdown]
# ## 5. Comparativa de Muk y Primeape a traves de un diagrama de araña

# %% [markdown]
# ## 6. ¿Cual es la relación de Defensa y Ataque de los pokemons? LA escala de colores se tiene que hacer con la variable Speed

# %% [markdown]
# ## 7. A través de un bubble chart hay que comparar los pokemos de las distintas generaciones en base a las variables de Attack y Defense
